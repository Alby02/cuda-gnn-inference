# %%
# !g++ --version
# Out:
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%bash
# nvidia-smi
# nvcc --version
# Out:
# Thu Jul  2 20:18:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content/drive/MyDrive/;
# git clone https://github.com/Alby02/cuda-gnn-inference.git;
# pip install meson ninja;
# Out:
# Collecting meson
#   Downloading meson-1.11.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading meson-1.11.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.0 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: ninja, meson
# Successfully installed meson-1.11.1 ninja-1.13.0
# fatal: destination path 'cuda-gnn-inference' already exists and is not an empty directory.

# %%
# %%bash
# cd /content/drive/MyDrive/cuda-gnn-inference;
# meson setup builddir;
# Out:
# The Meson build system
# Version: 1.11.1
# Source dir: /content/drive/MyDrive/cuda-gnn-inference
# Build dir: /content/drive/MyDrive/cuda-gnn-inference/builddir
# Build type: native build
# Project name: cuda-gnn-inference
# Project version: 0.1
# C++ compiler for the host machine: c++ (gcc 11.4.0 "c++ (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0")
# C++ linker for the host machine: c++ ld.bfd 2.38
# Cuda compiler for the host machine: nvcc (nvcc 12.8.93)
# Cuda linker for the host machine: nvcc nvlink 12.8.93
# Host machine cpu family: x86_64
# Host machine cpu: x86_64
# Build targets in project: 1
#
# Found ninja-1.13.0.git.kitware.jobserver-pipe-1 at /usr/local/bin/ninja
