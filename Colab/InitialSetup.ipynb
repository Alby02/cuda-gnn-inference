# %%
# !g++ --version

# %%
# %%bash
# nvidia-smi
# nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%bash
# set -euo pipefail
# DRIVE_ROOT=/content/drive/MyDrive
# PROJECT=$DRIVE_ROOT/cuda-gnn-inference
#
# if [ -d "$PROJECT/.git" ]; then
#   echo "Repository già presente in $PROJECT"
# elif [ -e "$PROJECT" ]; then
#   echo "Errore: $PROJECT esiste ma non è un repository Git." >&2
#   echo "Rinomina o rimuovi quella cartella, poi riesegui questa cella." >&2
#   exit 1
# else
#   git clone https://github.com/Alby02/cuda-gnn-inference.git "$PROJECT"
# fi
# test -f "$PROJECT/pyproject.toml"

# %%
# %pip install -q meson ninja networkit scipy

# %%
# %%bash
# set -euo pipefail
# PROJECT=/content/drive/MyDrive/cuda-gnn-inference
# cd "$PROJECT"
#
# if [ -d builddir/meson-private ]; then
#   meson setup --reconfigure builddir
# else
#   meson setup builddir
# fi
